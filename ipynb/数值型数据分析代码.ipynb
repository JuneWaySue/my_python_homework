# %% [markdown]
# ### 导包

# %%
import re
import time
import emoji
# import jieba
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from pyecharts import options as opts
from pyecharts.charts import WordCloud
from pyecharts.render import make_snapshot
from snapshot_selenium import snapshot

# %% [markdown]
# ### 相关画图参数配置及函数定义

# %%
# 函数的作用：在柱状图上标记其数值
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0,3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
# 画图的全局参数配置
plt.rcParams['font.sans-serif'] = ['SimHei'] # 黑体
plt.rcParams['font.size'] = 15 # 字号为15
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像时'-'显示为方块的问题

# %% [markdown]
# ### 前5条数据展示

# %%
f=open('./data/清洗后的数据.csv',encoding='utf-8')
df=pd.read_csv(f)
df=df.fillna('')
df.head()
# Out:
#      平台           评价id                 购买日期                 评论日期    用户名  \
# 0  淘宝天猫  1076958484029  2020-03-14 22:06:59  2020-03-16 22:12:38  h***v
# 1  淘宝天猫  1076958220208  2020-03-16 16:03:30  2020-03-16 22:11:19  韦***2
# 2  淘宝天猫  1077449498185  2020-03-16 19:35:27  2020-03-16 19:38:10  a***g
# 3  淘宝天猫  1077443646752  2020-03-16 18:40:06  2020-03-16 18:42:03  m***9
# 4  淘宝天猫  1077185661251  2020-03-16 17:48:26  2020-03-16 17:53:42  k***e
#
#                                      购买手机的配置信息  \
# 0   网络类型:4G全网通;机身颜色:赤茶橘;套餐类型:官方标配;存储容量:8+256GB
# 1   网络类型:4G全网通;机身颜色:亮黑色;套餐类型:官方标配;存储容量:8+256GB
# 2   网络类型:4G全网通;机身颜色:极光色;套餐类型:官方标配;存储容量:8+128GB
# 3  网络类型:4G全网通;机身颜色:天空之境;套餐类型:官方标配;存储容量:8+128GB
# 4   网络类型:4G全网通;机身颜色:亮黑色;套餐类型:官方标配;存储容量:8+128GB
#
#                                                 评价内容 追评内容 追评日期 追评相隔的时间
# 0                                         买个妈妈的，她很满意
# 1                                     已经买入第二台了 质量真不错
# 2  发货很快，拍照确实很清楚，通话很清晰，屏幕显示效果很好，手机运行非常不错，已第2次在他家买手...
# 3                 音质：第二次买了，帮朋友买的，价格降了，产品一样的好，好评！全5分。
# 4                   还不错，挺漂亮的，拍照效果杠杠滴，送老公的，快递很快哦，包装很好

# %% [markdown]
# ### 4月11日开售以来华为p30pro手机的日销量图

# %%
ah=[]
for i in df['评论日期'].values:
    ah.append(re.findall('\d{4}-\d{2}-\d{2}',i)[0])
rq=pd.DataFrame(pd.Series(ah).value_counts().values,pd.Series(ah).value_counts().index).sort_index()
xs = [datetime.strptime(d, '%Y-%m-%d').date() for d in list(rq.index)]
plt.figure(figsize=(13,5))
plt.bar(xs,list(rq[0].values),color='c')
plt.title('日销量趋势图')
plt.ylabel('销量')
plt.tight_layout()
plt.savefig('./data/pictures/日销量趋势图.jpg')
plt.show()

# %% [markdown]
# ### 不同颜色的手机销量图

# %%
ys=['亮黑色','珠光贝母','极光色','嫣紫色','天空之境','赤茶橘','墨玉蓝']
sku=dict(zip(ys,[int(i) for i in list('0'*len(ys))]))
for i,j in df['购买手机的配置信息'].value_counts().items():
    for y in ys:
        if y in i:
            sku[y]=sku[y]+j
            break
plt.figure(figsize=(10,6))
a=plt.bar(sku.keys(),sku.values(),color='c')
autolabel(a)
plt.ylabel('销量')
plt.title('不同颜色的手机销量图')
plt.tight_layout()
plt.savefig('./data/pictures/不同颜色的手机销量图.jpg')
plt.show()

# %% [markdown]
# ### 不同配置的手机销量图

# %%
def divice(s):
    if re.search('8GB\+128GB|8\+128GB',s) is not None:
        return '8GB+128GB'
    elif re.search('8GB\+256GB|8\+256GB',s) is not None:
        return '8GB+256GB'
    elif re.search('8GB\+512GB|8\+512GB',s) is not None:
        return '8GB+512GB'
    else:
        return '8GB+128GB'
df1=df['购买手机的配置信息'].apply(lambda s:divice(s))
plt.figure(figsize=(10,5))
explode=(0.05,0.03,0)
plt.pie(df1.value_counts().values,autopct='%.0f%%',labels=df1.value_counts().index,radius=1,
        textprops={'fontsize':20},explode=explode,shadow=True)
plt.tight_layout()
plt.savefig('./data/pictures/不同配置的手机销量占比饼图.jpg')
plt.show()

# %% [markdown]
# ### 评价内容经过分词后的词云图

# %%
f=open('./data/分词后的评论数据.csv',encoding='utf-8')
all_comments=pd.read_csv(f)
all_comments=all_comments.fillna('')
words={}
for i in all_comments['分词处理后的评论'].apply(lambda x:x.split()).values:
    for w in i:
        if w not in words:
            words[w]=1
        else:
            words[w]+=1
words=sorted(words.items(), key=lambda x: x[1], reverse=True)
c=WordCloud()
c.add(series_name="", data_pair=list(words)[:100],word_size_range=[20,100],shape='diamond')
c.set_global_opts(
    title_opts=opts.TitleOpts(
        title="", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
    ),
    tooltip_opts=opts.TooltipOpts(is_show=True),
)
c.render_notebook()
# make_snapshot(snapshot,c.render(),'词云.png',is_remove_html=True)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="cfba07ad53ba46c3b46176697bbb552e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_cfba07ad53ba46c3b46176697bbb552e = echarts.init(
#                     document.getElementById('cfba07ad53ba46c3b46176697bbb552e'), 'white', {renderer: 'canvas'});
#                 var option_cfba07ad53ba46c3b46176697bbb552e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u624b\u673a",
#                     "value": 24515,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(91,108,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u534e\u4e3a",
#                     "value": 24382,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,37,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": 10822,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,39,109)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62cd\u7167",
#                     "value": 10802,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,108,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u652f\u6301",
#                     "value": 8611,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,18,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u559c\u6b22",
#                     "value": 8137,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,54,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6536\u5230",
#                     "value": 5063,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(62,152,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u771f\u7684",
#                     "value": 4629,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(9,61,41)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u624b\u611f",
#                     "value": 4374,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,150,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u611f\u89c9",
#                     "value": 4373,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(42,91,140)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u901f\u5ea6",
#                     "value": 4179,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,109,111)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c4f\u5e55",
#                     "value": 4003,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,90,75)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u529f\u80fd",
#                     "value": 4001,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(131,150,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7269\u6d41",
#                     "value": 3978,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,75,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ee1\u610f",
#                     "value": 3910,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(38,103,9)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "p30pro",
#                     "value": 3890,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,126,48)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88\u5feb",
#                     "value": 3884,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,108,87)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6d41\u7545",
#                     "value": 3853,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,131,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u597d\u770b",
#                     "value": 3450,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(141,53,127)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6f02\u4eae",
#                     "value": 3441,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,30,24)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u989c\u8272",
#                     "value": 3387,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,156,101)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6548\u679c",
#                     "value": 3284,
#                     "textStyle": {
#                         "normal": {
#                             "color":
